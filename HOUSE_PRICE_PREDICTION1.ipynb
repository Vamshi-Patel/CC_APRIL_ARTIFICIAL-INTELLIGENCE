# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy.stats import boxcox
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics
from mpl_toolkits import mplot3d
from matplotlib import cm
from matplotlib.ticker import LinearLocator
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# **Loading and Describing Data**

# %%
data="/kaggle/input/house-price-prediction-dataset/train.csv"
df=pd.read_csv(data)
df.head(6)
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
# 5     Owner                   0     0        3       BHK  1250.000000
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE   LATITUDE  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910  77.597960
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538  76.644605
# 2              1       1             Jigani,Bangalore  12.778033  77.632191
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300  77.344500
# 4              0       1             New Town,Kolkata  22.592200  88.484911
# ...

# %% [markdown]
# **Description**
#
# This dataset contains information about houses and there prices in india.
#
#  **Column Descriptions**
#
# * **UNDER_CONSTRUCTION**:Under consturction or not(0 or 1)
# * **RERA**:Rera-approved or not(0 or 1)
# * **BHK_NO**:Number of bedrooms
# * **BHK_OR_RK**:Configuration of the house.BHK stands for "Bedroom Hall Kitchen" while RK stads for "Room Kitchen"
# * **SQUARE_FT**:Area of the house in suare feet.
# * **READY_TO_MOVE**:Property marked as ready to move or noe(0 or 1)
# * **RESALE**:Property marked as resale or not(0 or 1).
# * **ADDRESS**:The properties location(town).
# * **LONGITUDE**:Longitude of the property.
# * **LATITUDE**:Latitude of the property.
# * **TARGET(PRICE_IN_LACS)**:The price are in "lacs"(100k)

# %%
df.describe()
# Out:
#        UNDER_CONSTRUCTION          RERA       BHK_NO.     SQUARE_FT  \
# count        29451.000000  29451.000000  29451.000000  2.945100e+04
# mean             0.179756      0.317918      2.392279  1.980217e+04
# std              0.383991      0.465675      0.879091  1.901335e+06
# min              0.000000      0.000000      1.000000  3.000000e+00
# 25%              0.000000      0.000000      2.000000  9.000211e+02
# 50%              0.000000      0.000000      2.000000  1.175057e+03
# 75%              0.000000      1.000000      3.000000  1.550688e+03
# max              1.000000      1.000000     20.000000  2.545455e+08
#
#        READY_TO_MOVE        RESALE     LONGITUDE      LATITUDE  \
# count   29451.000000  29451.000000  29451.000000  29451.000000
# mean        0.820244      0.929578     21.300255     76.837695
# std         0.383991      0.255861      6.205306     10.557747
# min         0.000000      0.000000    -37.713008   -121.761248
# ...

# %% [markdown]
# This is a datset of around 29k houses.Most of the are not under construction,have to bedrooms,and are ready to move.The house have an average of 20k square ft,and have a mean price of 143lacs.
#
# its also apparent fom the table that there may be some outliers,since max values for no of rooms,square ft,and houses prices are all significantly hogher than the mean,and even the 75 percentile.
#
# **Clean Data**
#
# Before making the linear regression models,the data must be cleaned up.
#
# **Check for Missimg Values**
#
# Missing values will interfere with the plotting,when the x and y columns have a different numbers of values,or values don't match up.

# %%
df.columns[df.isnull().any()]
df.isnull().sum()
# Out:
# POSTED_BY                0
# UNDER_CONSTRUCTION       0
# RERA                     0
# BHK_NO.                  0
# BHK_OR_RK                0
# SQUARE_FT                0
# READY_TO_MOVE            0
# RESALE                   0
# ADDRESS                  0
# LONGITUDE                0
# LATITUDE                 0
# TARGET(PRICE_IN_LACS)    0
# dtype: int64

# %% [markdown]
# **Check for Outliers**
#
# If there are outliers in the data,they will affect the linear regression more than inteded.therefore,the outliers need to be found and clean up.
#
# This can be done by first finding the numeric columns,and then making boxs plots, to visualize them individually.That will provide a visual of the outliers,which will be outside of the box and whiskers.

# %%
data=df.copy()
data=data.select_dtypes(include=["float64","int64"])
data.head()
# Out:
#    UNDER_CONSTRUCTION  RERA  BHK_NO.    SQUARE_FT  READY_TO_MOVE  RESALE  \
# 0                   0     0        2  1300.236407              1       1
# 1                   0     0        2  1275.000000              1       1
# 2                   0     0        2   933.159722              1       1
# 3                   0     1        2   929.921143              1       1
# 4                   1     0        2   999.009247              0       1
#
#    LONGITUDE   LATITUDE  TARGET(PRICE_IN_LACS)
# 0  12.969910  77.597960                   55.0
# 1  12.274538  76.644605                   51.0
# 2  12.778033  77.632191                   43.0
# 3  28.642300  77.344500                   62.5
# 4  22.592200  88.484911                   60.5

# %%
column_list=['BHK_NO.','SQUARE_FT','TARGET(PRICE_IN_LACS)']
for col in column_list:
    sns.boxplot(x=data[col])
    plt.xlabel(col)
    plt.show()

# %%
#Removing outliers
#get the lists of the columns
sqft=list(df['SQUARE_FT'])
rooms=list(df['BHK_NO.'])
price=list(df['TARGET(PRICE_IN_LACS)'])

# get rid of the higest values in sqft and prices,since that's where the outliers are 
new_sqft=sqft
for i in range(200):
    x=sqft.index(sorted(sqft)[-1])
    del new_sqft[x]
    del rooms[x]
    del price[x]
new_price=price
for i in range(100):
    y=price.index(sorted(price)[-1])
    del new_sqft[y]
    del rooms[y]
    del new_price[y]

# %%
sns.boxplot(x=new_sqft)
plt.show()

# %%
sns.boxplot(x=rooms)
plt.show()

# %%
sns.boxplot(x=price)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **Linear Regression**
#
# Linear regression can be used to model our data for predictions.it takes two columns of the data, graphs it,and makes aline of the best fit in the format of y=mx+b.it can also show the relation between to different columns of the data,as well as the trend.
#
# **Total Area vs.House Price**
#
# A possitive correlation between the total areas of the house and the pricing is ecpected
#
# **With Outliers**
#
# For comparison,both the models with and without outliers will be graphed.

# %%
g=sns.regplot(x=df['SQUARE_FT'],y=df["TARGET(PRICE_IN_LACS)"],ci=None,scatter_kws={'color':'r','s':9})
g.set_title("Total Area vs House Price")
g.set_ylabel("House price (lacs)")
g.set_xlabel('Area (sqft)')
plt.show()
X=df['SQUARE_FT'].values.reshape(-1,1)
y=df['TARGET(PRICE_IN_LACS)']
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3, random_state=1)
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,y_train)
predictions=lin_reg.predict(X_test)

print("intercept (m):",model.intercept_)
print("coef (b):",model.coef_)
print("RScore (r^2):",model.score(X_test,y_test))
print("MAE:",metrics.mean_absolute_error(y_test,predictions))
# Out:
# intercept (m): 139.71963280033685
# coef (b): [0.00012774]
# RScore (r^2): 0.1090767624511143
# MAE: 135.84630921926123

# %% [markdown]
# **Without Outliers**

# %%
g=sns.regplot(x=new_sqft,y=new_price,ci=None,scatter_kws={'color':'r','s':9})
g.set_title("Total Area vs House Price *without outliers")
g.set_ylabel("House price (Lacs)")
g.set_xlabel("Area (sqft)" )
plt.show()

X=np.array(new_sqft).reshape(-1,1)
y=new_price
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,y_train)
predictions=lin_reg.predict(X_test)

             
print("intercept(m):",model.intercept_)
print("coef(b):",model.coef_)
print("RScore (r^2):",model.score(X_test,y_test))
print("MAE:",metrics.mean_absolute_error(y_test,predictions))
# Out:
# intercept(m): -20.261967245747
# coef(b): [0.08845136]
# RScore (r^2): 0.28149497751399666
# MAE: 52.91762692339938

# %%
g=sns.jointplot(x="BHK_NO.",y="TARGET(PRICE_IN_LACS)",data=df,kind="reg")
g.fig.suptitle("# of Bedrooms vs House Prices")
g.set_axis_labels("# of Bedrooms","House Prices")
plt.show()

# %%
X=df['BHK_NO.'].values.reshape(-1,1)
y=df['TARGET(PRICE_IN_LACS)']

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,y_train)
predictions=lin_reg.predict(X_test)

print("intercept (m):",model.intercept_)
print("coef (b):",model.coef_)
print("RScore (r^2):",model.score(X_test,y_test))
print("MAE:",metrics.mean_absolute_error(y_test,predictions))
# Out:
# intercept (m): -62.83149395027604
# coef (b): [86.00946026]
# RScore (r^2): 0.011226763744550783
# MAE: 131.08673718659676

# %%
g=sns.regplot(x=rooms,y=new_price,ci=None,scatter_kws={'color':'r','s':9})
g.set_title("# of bedrooms vs House Prices")
g.set_ylabel("House Price (Lacs)")
g.set_xlabel("# of Bedrooms")
plt.show()

X=np.array(rooms).reshape(-1,1)
y=new_price
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,y_train)
predictions=lin_reg.predict(X_test)

print("intercept (m):",model.intercept_)
print("coef (b):",model.coef_)
print("RScore (r^2)):",model.score(X_test,y_test))
print("MAE:",metrics.mean_absolute_error(y_test,predictions))
# Out:
# intercept (m): -46.41086673847708
# coef (b): [59.26236206]
# RScore (r^2)): 0.16529551378117202
# MAE: 59.61255293112337

# %%
X=df[['BHK_NO.','SQUARE_FT']]
y=df['TARGET(PRICE_IN_LACS)']
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=5, random_state=1)
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,y_train)
predictions=lin_reg.predict(X_test)

print("intercept (m):",model.intercept_)
print("coef (b) of each independent variable:",model.coef_)
print("RScore (r^2):",model.score(X_test,y_test))
print("MAE:",metrics.mean_absolute_error(y_test,predictions))
# Out:
# intercept (m): -56.551605004438045
# coef (b) of each independent variable: [8.21304752e+01 1.38912846e-04]
# RScore (r^2): -0.20864616109671474
# MAE: 1425.7260374382886

# %% [markdown]
# **Without Outliers**

# %%
X=np.array([np.array(rooms),np.array(new_sqft)])
y=np.array(new_price)
X=X.transpose()
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.5, random_state=1)
lin_reg=LinearRegression()
model=lin_reg.fit(X_train,y_train)
predictions = lin_reg.predict(X_test)

print("intercept (m):",model.intercept_)
print("coef (b) of each independent variable:",model.coef_)
print("RScore (r^2):",model.score(X_test,y_test))
print("MAE:",metrics.mean_absolute_error(y_test,predictions))
# Out:
# intercept (m): -33.32610887709838
# coef (b) of each independent variable: [11.52397048  0.07736261]
# RScore (r^2): 0.28091600933065575
# MAE: 53.744756754052716

# %% [markdown]
# **Analysis**
#
#
# Evidently,the model without outliers has much a smaller mean absolute error ,and is much closer to the actual data.Nevertheless,it's still very inaccurate,with only a 0.281 r-value
#
# in comparison with the simple linear regressions,the multiple linear regression is more accurate than the "Bedrooms vs House Price"linreg,and veryclose to the "Area vs Home Price"model(which is barely more accurate than this one by a R score of 0.0005).This may be beacuse of the lowercorrelation of bedrooms to house price,so that when the less correlated bedrooms column,the model became less correlated than just the square feet column on its own.
#
# **Conclusion**
#
# Each of the columns had an extreamly low positive correlation with the house prices,with the highest correlated model beign "Arae vs House Price",with an R-score of 0.281,and a MAE of 52.918.This shows that house prices are not determined by the number of bedrooms,the total area of the house, or a combination of the two.it could be that the prices are more correlated with one or more of the columns that wee not model,like longititude and latitude,which should be worth modelling time permitted.
#
# Some bias may be present in the process of removing the outliers.the amount of outliers were too long for all of them to be removed,so some decisions visually on the box plots were made for how many outliers to remove,since the square root column had the most numberof outliers, more data points were outliers in the columns were removed from the dataset.meanwhile,the bedrooms column was nos not as affacted by its outliers, so non of the outliers from that column were removed from the dataset.it could be abecause of these that the model involving the square root column had a higer correlation then the model with the bedrooms column.
#
# in addition,the exact source of these dataset is rather unkown and unverified, leading to the possibility of bias in the collection of data itself.
